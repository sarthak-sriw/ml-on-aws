# %%
region = "us-east-1"
#s3 buckeet name
bucket = "mybucketsriw"

# %%
import boto3

po = boto3.client('polly',region)
po.synthesize

# %%
res = po.synthesize_speech(Text = "using text to speech conversion by using amazon polly resource",
                    OutputFormat='mp3',VoiceId= 'Aditi')

# %%
res
# Out:
# {'ResponseMetadata': {'RequestId': 'f87669f1-c657-446e-90b6-cb5f9b4ca26f',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f87669f1-c657-446e-90b6-cb5f9b4ca26f',
#    'x-amzn-requestcharacters': '62',
#    'content-type': 'audio/mpeg',
#    'transfer-encoding': 'chunked',
#    'date': 'Tue, 08 Jun 2021 14:54:25 GMT'},
#   'RetryAttempts': 0},
#  'ContentType': 'audio/mpeg',
#  'RequestCharacters': '62',
#  'AudioStream': <botocore.response.StreamingBody at 0x1e3f1d57708>}

# %%
res['AudioStream']

# %%
file = open("myaudio.mp3","wb")
file.write(res['AudioStream'].read())
file.close()

# %%
import IPython
IPython.display.Audio("myaudio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
